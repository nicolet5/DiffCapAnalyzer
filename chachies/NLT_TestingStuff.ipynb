# %%
import chachifuncs
from chachifuncs import load_sep_cycles, clean_calc_sep_smooth
from chachifuncs import calc_dv_dqdv, drop_0_dv
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
import glob 
import os
from pandas import ExcelWriter

def get_clean_cycles(import_filepath, save_filepath): 
    """Imports all separated out cycles in given path and cleans them and saves them in the specified filepath"""
    rootdir = import_filepath
    file_list = [f for f in glob.glob(os.path.join(rootdir,'*.xlsx'))] #iterate through dir to get excel files 
    d = {} #initiate dict for data storage
    count = 0
    for file in file_list:
        count += 1
        name = os.path.split(file)[1].split('.')[0]
        data = pd.read_excel(file)
        charge, discharge = clean_calc_sep_smooth(data, 21, 3)
        clean_data = charge.append(discharge)
        clean_cycle = {name : clean_data}
        d.update(clean_cycle)
        print("adding file to dictionary" + str(count) + ' ' + str(name))
    for key in d:
        clean_cycle_df = d[key]
        cyclename = key 
        writer = ExcelWriter(save_filepath + cyclename + 'Clean'+ '.xlsx')
        clean_cycle_df.to_excel(writer)
        writer.save()
       # save_sep_cycles_xlsx(d, cyclename, save_filepath) 
    print('All cycles cleaned and saved in folder.')
    return

# %%
def get_clean_sets(import_filepath, save_filepath): 
    """Imports all clean cycles of data from import path and appends them into complete sets of battery data, saved into save_filepath"""
    rootdir = import_filepath
    file_list = [f for f in glob.glob(os.path.join(rootdir,'*.xlsx'))] #iterate through dir to get excel files 
    d = {} #initiate dict for data storage
    count = 0
    list_bats = [] 
    for file in file_list:
        count += 1
        name = os.path.split(file)[1].split('.')[0]
        batname = name.split('-')[0]
        if batname not in list_bats:
            list_bats.append(batname)
        else: None  
            
    set_dict = {}
    
    for i in range(len(list_bats)): 
        batID = list_bats[i] 
        setdf = pd.DataFrame()
        for file in file_list:
            name = os.path.split(file)[1].split('.')[0]
            batname = name.split('-')[0]
            if batname == batID:
                df = pd.read_excel(file)
                setdf = setdf.append(df, ignore_index=True)
            else:
                None 
        setdf = setdf.sort_values(['Data_Point'], ascending = True)
        newset = {batID : setdf}
        set_dict.update(newset) 
        
    for key, value in set_dict.items():
        writer = ExcelWriter(save_filepath + key + '.xlsx')
        value.to_excel(writer)
        writer.save() 
                
    print('All clean cycles appended and saved in folder.')
    return

# %%
load_sep_cycles('NLT_Test/NLT_TestSource/', 'NLT_Test/NLT_TestSepCycles/')
# I had to make this first directory (source) just as a small set of the data to test this code on, and then had to make a 
#directory for where I wanted my cycles to be stored in once they were seperated out. This code takes a while to run.
# Out:
# adding file 1 3_4_14_1C_Cycle
# adding file 2 CS2_33_1_24_11
# adding file 3 CS2_33_9_27_10
# All data separated into cycles and saved

# %%
get_clean_cycles('NLT_Test/NLT_TestSepCycles/', 'NLT_Test/NLT_TestCleanCycles/')
# Out:
# adding file to dictionary1 3_4_14_1C_Cycle-Cycle1
# adding file to dictionary2 3_4_14_1C_Cycle-Cycle10
# adding file to dictionary3 3_4_14_1C_Cycle-Cycle100
# adding file to dictionary4 3_4_14_1C_Cycle-Cycle11
# adding file to dictionary5 3_4_14_1C_Cycle-Cycle12
# adding file to dictionary6 3_4_14_1C_Cycle-Cycle13
# adding file to dictionary7 3_4_14_1C_Cycle-Cycle14
# adding file to dictionary8 3_4_14_1C_Cycle-Cycle15
# adding file to dictionary9 3_4_14_1C_Cycle-Cycle16
# adding file to dictionary10 3_4_14_1C_Cycle-Cycle17
# adding file to dictionary11 3_4_14_1C_Cycle-Cycle18
# adding file to dictionary12 3_4_14_1C_Cycle-Cycle19
# adding file to dictionary13 3_4_14_1C_Cycle-Cycle2
# adding file to dictionary14 3_4_14_1C_Cycle-Cycle20
# adding file to dictionary15 3_4_14_1C_Cycle-Cycle21
# adding file to dictionary16 3_4_14_1C_Cycle-Cycle22
# adding file to dictionary17 3_4_14_1C_Cycle-Cycle23
# adding file to dictionary18 3_4_14_1C_Cycle-Cycle24
# adding file to dictionary19 3_4_14_1C_Cycle-Cycle25
# adding file to dictionary20 3_4_14_1C_Cycle-Cycle26
# adding file to dictionary21 3_4_14_1C_Cycle-Cycle27
# adding file to dictionary22 3_4_14_1C_Cycle-Cycle28
# adding file to dictionary23 3_4_14_1C_Cycle-Cycle29
# adding file to dictionary24 3_4_14_1C_Cycle-Cycle3
# adding file to dictionary25 3_4_14_1C_Cycle-Cycle30
# adding file to dictionary26 3_4_14_1C_Cycle-Cycle31
# adding file to dictionary27 3_4_14_1C_Cycle-Cycle32
# adding file to dictionary28 3_4_14_1C_Cycle-Cycle33
# adding file to dictionary29 3_4_14_1C_Cycle-Cycle34
# adding file to dictionary30 3_4_14_1C_Cycle-Cycle35
# adding file to dictionary31 3_4_14_1C_Cycle-Cycle36
# adding file to dictionary32 3_4_14_1C_Cycle-Cycle37
# adding file to dictionary33 3_4_14_1C_Cycle-Cycle38
# adding file to dictionary34 3_4_14_1C_Cycle-Cycle39
# adding file to dictionary35 3_4_14_1C_Cycle-Cycle4
# adding file to dictionary36 3_4_14_1C_Cycle-Cycle40
# adding file to dictionary37 3_4_14_1C_Cycle-Cycle41
# adding file to dictionary38 3_4_14_1C_Cycle-Cycle42
# adding file to dictionary39 3_4_14_1C_Cycle-Cycle43
# adding file to dictionary40 3_4_14_1C_Cycle-Cycle44
# adding file to dictionary41 3_4_14_1C_Cycle-Cycle45
# adding file to dictionary42 3_4_14_1C_Cycle-Cycle46
# adding file to dictionary43 3_4_14_1C_Cycle-Cycle47
# adding file to dictionary44 3_4_14_1C_Cycle-Cycle48
# adding file to dictionary45 3_4_14_1C_Cycle-Cycle49
# adding file to dictionary46 3_4_14_1C_Cycle-Cycle5
# adding file to dictionary47 3_4_14_1C_Cycle-Cycle50
# adding file to dictionary48 3_4_14_1C_Cycle-Cycle51
# adding file to dictionary49 3_4_14_1C_Cycle-Cycle52
# adding file to dictionary50 3_4_14_1C_Cycle-Cycle53
# adding file to dictionary51 3_4_14_1C_Cycle-Cycle54
# adding file to dictionary52 3_4_14_1C_Cycle-Cycle55
# adding file to dictionary53 3_4_14_1C_Cycle-Cycle56
# adding file to dictionary54 3_4_14_1C_Cycle-Cycle57
# adding file to dictionary55 3_4_14_1C_Cycle-Cycle58
# adding file to dictionary56 3_4_14_1C_Cycle-Cycle59
# adding file to dictionary57 3_4_14_1C_Cycle-Cycle6
# adding file to dictionary58 3_4_14_1C_Cycle-Cycle60
# adding file to dictionary59 3_4_14_1C_Cycle-Cycle61
# adding file to dictionary60 3_4_14_1C_Cycle-Cycle62
# adding file to dictionary61 3_4_14_1C_Cycle-Cycle63
# adding file to dictionary62 3_4_14_1C_Cycle-Cycle64
# adding file to dictionary63 3_4_14_1C_Cycle-Cycle65
# adding file to dictionary64 3_4_14_1C_Cycle-Cycle66
# adding file to dictionary65 3_4_14_1C_Cycle-Cycle67
# adding file to dictionary66 3_4_14_1C_Cycle-Cycle68
# adding file to dictionary67 3_4_14_1C_Cycle-Cycle69
# adding file to dictionary68 3_4_14_1C_Cycle-Cycle7
# adding file to dictionary69 3_4_14_1C_Cycle-Cycle70
# adding file to dictionary70 3_4_14_1C_Cycle-Cycle71
# adding file to dictionary71 3_4_14_1C_Cycle-Cycle72
# adding file to dictionary72 3_4_14_1C_Cycle-Cycle73
# adding file to dictionary73 3_4_14_1C_Cycle-Cycle74
# adding file to dictionary74 3_4_14_1C_Cycle-Cycle75
# adding file to dictionary75 3_4_14_1C_Cycle-Cycle76
# adding file to dictionary76 3_4_14_1C_Cycle-Cycle77
# adding file to dictionary77 3_4_14_1C_Cycle-Cycle78
# adding file to dictionary78 3_4_14_1C_Cycle-Cycle79
# adding file to dictionary79 3_4_14_1C_Cycle-Cycle8
# adding file to dictionary80 3_4_14_1C_Cycle-Cycle80
# adding file to dictionary81 3_4_14_1C_Cycle-Cycle81
# adding file to dictionary82 3_4_14_1C_Cycle-Cycle82
# adding file to dictionary83 3_4_14_1C_Cycle-Cycle83
# adding file to dictionary84 3_4_14_1C_Cycle-Cycle84
# adding file to dictionary85 3_4_14_1C_Cycle-Cycle85
# adding file to dictionary86 3_4_14_1C_Cycle-Cycle86
# adding file to dictionary87 3_4_14_1C_Cycle-Cycle87
# adding file to dictionary88 3_4_14_1C_Cycle-Cycle88
# adding file to dictionary89 3_4_14_1C_Cycle-Cycle89
# adding file to dictionary90 3_4_14_1C_Cycle-Cycle9
# adding file to dictionary91 3_4_14_1C_Cycle-Cycle90
# adding file to dictionary92 3_4_14_1C_Cycle-Cycle91
# adding file to dictionary93 3_4_14_1C_Cycle-Cycle92
# adding file to dictionary94 3_4_14_1C_Cycle-Cycle93
# adding file to dictionary95 3_4_14_1C_Cycle-Cycle94
# adding file to dictionary96 3_4_14_1C_Cycle-Cycle95
# adding file to dictionary97 3_4_14_1C_Cycle-Cycle96
# adding file to dictionary98 3_4_14_1C_Cycle-Cycle97
# adding file to dictionary99 3_4_14_1C_Cycle-Cycle98
# adding file to dictionary100 3_4_14_1C_Cycle-Cycle99
# adding file to dictionary101 CS2_33_1_24_11-Cycle1
# adding file to dictionary102 CS2_33_1_24_11-Cycle10
# adding file to dictionary103 CS2_33_1_24_11-Cycle11
# adding file to dictionary104 CS2_33_1_24_11-Cycle12
# adding file to dictionary105 CS2_33_1_24_11-Cycle13
# adding file to dictionary106 CS2_33_1_24_11-Cycle14
# adding file to dictionary107 CS2_33_1_24_11-Cycle15
# adding file to dictionary108 CS2_33_1_24_11-Cycle16
# adding file to dictionary109 CS2_33_1_24_11-Cycle17
# adding file to dictionary110 CS2_33_1_24_11-Cycle18
# adding file to dictionary111 CS2_33_1_24_11-Cycle19
# adding file to dictionary112 CS2_33_1_24_11-Cycle2
# adding file to dictionary113 CS2_33_1_24_11-Cycle20
# adding file to dictionary114 CS2_33_1_24_11-Cycle21
# adding file to dictionary115 CS2_33_1_24_11-Cycle22
# adding file to dictionary116 CS2_33_1_24_11-Cycle23
# adding file to dictionary117 CS2_33_1_24_11-Cycle24
# adding file to dictionary118 CS2_33_1_24_11-Cycle25
# adding file to dictionary119 CS2_33_1_24_11-Cycle26
# adding file to dictionary120 CS2_33_1_24_11-Cycle27
# adding file to dictionary121 CS2_33_1_24_11-Cycle28
# adding file to dictionary122 CS2_33_1_24_11-Cycle29
# adding file to dictionary123 CS2_33_1_24_11-Cycle3
# adding file to dictionary124 CS2_33_1_24_11-Cycle30
# adding file to dictionary125 CS2_33_1_24_11-Cycle31
# adding file to dictionary126 CS2_33_1_24_11-Cycle32
# adding file to dictionary127 CS2_33_1_24_11-Cycle33
# adding file to dictionary128 CS2_33_1_24_11-Cycle34
# adding file to dictionary129 CS2_33_1_24_11-Cycle35
# adding file to dictionary130 CS2_33_1_24_11-Cycle36
# adding file to dictionary131 CS2_33_1_24_11-Cycle37
# adding file to dictionary132 CS2_33_1_24_11-Cycle38
# adding file to dictionary133 CS2_33_1_24_11-Cycle39
# adding file to dictionary134 CS2_33_1_24_11-Cycle4
# adding file to dictionary135 CS2_33_1_24_11-Cycle40
# adding file to dictionary136 CS2_33_1_24_11-Cycle41
# adding file to dictionary137 CS2_33_1_24_11-Cycle42
# adding file to dictionary138 CS2_33_1_24_11-Cycle43
# adding file to dictionary139 CS2_33_1_24_11-Cycle44
# adding file to dictionary140 CS2_33_1_24_11-Cycle45
# adding file to dictionary141 CS2_33_1_24_11-Cycle46
# adding file to dictionary142 CS2_33_1_24_11-Cycle47
# adding file to dictionary143 CS2_33_1_24_11-Cycle48
# adding file to dictionary144 CS2_33_1_24_11-Cycle49
# adding file to dictionary145 CS2_33_1_24_11-Cycle5
# adding file to dictionary146 CS2_33_1_24_11-Cycle6
# adding file to dictionary147 CS2_33_1_24_11-Cycle7
# adding file to dictionary148 CS2_33_1_24_11-Cycle8
# adding file to dictionary149 CS2_33_1_24_11-Cycle9
# adding file to dictionary150 CS2_33_9_27_10-Cycle1
